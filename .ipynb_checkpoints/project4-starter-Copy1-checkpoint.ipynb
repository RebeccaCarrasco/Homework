# %% [markdown]
# # Project 4
#
# In this project, you will analyze the admissions data in detail and build a model and explain it. It is more open ended so feel free to use all the various techniques that you have learnt so far.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
import seaborn as sns

# %% [markdown]
# ### What are the predictors and dependent variable ?

# %% [markdown]
# The dependant variable for this data set is admit - whether a sudent is admitted or not. The predictor variables are those that influence this outcome - gre and gpe scores and prestige

# %%
df_raw = pd.read_csv("../assets/admissions.csv")
df = df_raw.dropna() 
print df.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ### Intro: Write a problem Statement/ Specific hypothesis you have regarding admissions?

# %% [markdown]
# Admission to college is related to gre and gpa score

# %% [markdown]
# ### Dataset:  Find the distribution of admission, GRE, GPA and Prestige

# %%
df.plot(kind= "density",
        xlim=(-1,5))

# %% [markdown]
# ### FInd the correlation of each feature with admission

# %%
correlations = df.corr()
print correlations
print sns.heatmap(correlations)
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.181202  0.174116 -0.243563
# gre       0.181202  1.000000  0.382408 -0.124533
# gpa       0.174116  0.382408  1.000000 -0.060976
# prestige -0.243563 -0.124533 -0.060976  1.000000
# Axes(0.125,0.125;0.62x0.775)

# %% [markdown]
# ### How do you deal with the prestige feature?

# %% [markdown]
# Prestige is a categorical variable, to perform modelling dummy variables of N-1 must be created first. In this case 3 dummy variables would be created since prestige can take one of 4 values.

# %% [markdown]
# ### What is the best model and that model's parameter's for predicting admission? Hint: Use GridsearchCV and define what metric you use to find what is best.

# %% [markdown]
# Since the targtet variable takes one out of 2 variables then this is a classification probelem. Therefore we can use KNN or a decision tree to predict the outcome.

# %%
data = df.join(pd.get_dummies(df.prestige, prefix = 'school')) #because I can't spell prestige
print data.head()
# Out:
#    admit    gre   gpa  prestige  school_1.0  school_2.0  school_3.0  \
# 0      0  380.0  3.61       3.0         0.0         0.0         1.0
# 1      1  660.0  3.67       3.0         0.0         0.0         1.0
# 2      1  800.0  4.00       1.0         1.0         0.0         0.0
# 3      1  640.0  3.19       4.0         0.0         0.0         0.0
# 4      0  520.0  2.93       4.0         0.0         0.0         0.0
#
#    school_4.0
# 0         0.0
# 1         0.0
# 2         0.0
# 3         1.0
# 4         1.0

# %%
from sklearn import grid_search, cross_validation
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler



feature_set = data[['gre', 'gpa', 'school_2.0', 'school_3.0', 'school_4.0']]



scaler = StandardScaler()
scaler.fit(feature_set)  # Don't cheat - fit only on training data
new_data = scaler.transform(feature_set)

# %%
new_data = pd.DataFrame(new_data)
new_data.head()
# Out:
#           0         1         2         3         4
# 0 -1.798524  0.573457 -0.770959  1.510295 -0.450589
# 1  0.624209  0.731464 -0.770959  1.510295 -0.450589
# 2  1.835576  1.600504 -0.770959 -0.662122 -0.450589
# 3  0.451157 -0.532595 -0.770959 -0.662122  2.219318
# 4 -0.587158 -1.217294 -0.770959 -0.662122  2.219318

# %%
gs = grid_search.GridSearchCV(
    estimator=LogisticRegression(),
    param_grid={'C': [i for i in range(1, 10)]},
    cv=cross_validation.KFold(n=len(df), n_folds=10),
    scoring='roc_auc'
)

# %%
gs.fit(new_data, data.admit)
# Out:
# GridSearchCV(cv=sklearn.cross_validation.KFold(n=397, n_folds=10, shuffle=False, random_state=None),
#        error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'C': [1, 2, 3, 4, 5, 6, 7, 8, 9]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=0)

# %%
print gs.grid_scores_
print gs.best_estimator_
# Out:
# [mean: 0.67274, std: 0.09047, params: {'C': 1}, mean: 0.67167, std: 0.09138, params: {'C': 2}, mean: 0.67223, std: 0.09066, params: {'C': 3}, mean: 0.67191, std: 0.09087, params: {'C': 4}, mean: 0.67191, std: 0.09087, params: {'C': 5}, mean: 0.67191, std: 0.09087, params: {'C': 6}, mean: 0.67191, std: 0.09087, params: {'C': 7}, mean: 0.67191, std: 0.09087, params: {'C': 8}, mean: 0.67191, std: 0.09087, params: {'C': 9}]
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
gs.best_estimator_.coef_
# Out:
# array([[ 0.25373424,  0.29106919, -0.30562537, -0.58829082, -0.55572362]])

# %%
gs.best_score_
# Out:
# 0.67273772845407864

# %%
from sklearn.ensemble import RandomForestClassifier
feature_set = data[['gre', 'gpa', 'school_2.0', 'school_3.0', 'school_4.0']]
gs2 = grid_search.GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid={'n_estimators': [i for i in range(1, 5)], 'max_depth':[3,4,5]},
    cv=cross_validation.KFold(n=len(df), n_folds=5),
    scoring='roc_auc'
)

gs2.fit(new_data, data.admit)
# Out:
# GridSearchCV(cv=sklearn.cross_validation.KFold(n=397, n_folds=5, shuffle=False, random_state=None),
#        error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [1, 2, 3, 4], 'max_depth': [3, 4, 5]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=0)

# %%
print gs2.grid_scores_
print gs2.best_estimator_
gs2.best_score_
# Out:
# [mean: 0.57041, std: 0.07304, params: {'n_estimators': 1, 'max_depth': 3}, mean: 0.59168, std: 0.04495, params: {'n_estimators': 2, 'max_depth': 3}, mean: 0.63051, std: 0.05490, params: {'n_estimators': 3, 'max_depth': 3}, mean: 0.62965, std: 0.06213, params: {'n_estimators': 4, 'max_depth': 3}, mean: 0.57818, std: 0.05542, params: {'n_estimators': 1, 'max_depth': 4}, mean: 0.59227, std: 0.05275, params: {'n_estimators': 2, 'max_depth': 4}, mean: 0.60141, std: 0.08042, params: {'n_estimators': 3, 'max_depth': 4}, mean: 0.64682, std: 0.06106, params: {'n_estimators': 4, 'max_depth': 4}, mean: 0.57423, std: 0.02811, params: {'n_estimators': 1, 'max_depth': 5}, mean: 0.57761, std: 0.06536, params: {'n_estimators': 2, 'max_depth': 5}, mean: 0.60798, std: 0.06603, params: {'n_estimators': 3, 'max_depth': 5}, mean: 0.60998, std: 0.06396, params: {'n_estimators': 4, 'max_depth': 5}]
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=4, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=4, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 0.64682239545455045

# %% [markdown]
# ### What is the most important feature that contributes to the students probability of admission?

# %% [markdown]
# GPA is the feature that contibutes the most since it has the highest coefficient for both models

# %%
gs2.best_estimator_.feature_importances_
# Out:
# array([ 0.3656497 ,  0.48449629,  0.05186136,  0.08136407,  0.01662858])

# %%
gs.best_estimator_.coef_
# Out:
# array([[ 0.25373424,  0.29106919, -0.30562537, -0.58829082, -0.55572362]])

# %% [markdown]
# ### Visualize the model relative to prestige and GPA. HINT: Use the technique from the visualization of the flight delay model

# %%
data["lm_predict"] = gs.predict_proba(new_data)[:,1]

# %%
ax1 = plt.subplot(111)
school_features = ['school_1.0','school_2.0', 'school_3.0', 'school_4.0']
colors = ['blue', 'green', 'red', 'purple'] #selecting colours
for e, c in enumerate(colors):
    data[data[school_features[e]] == 1].plot(x='gpa', y='lm_predict', kind='scatter', color = c, ax=ax1)
ax1.set(title='Probability of Admission\n Based on GPA and Prestige')

lines, labels = ax1.get_legend_handles_labels()
ax1.legend(lines[:2], labels=school_features, loc='best')
# Out:
# /Users/RebeccaCarrasco/Documents/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:504: UserWarning: You have mixed positional and keyword arguments, some input will be discarded.
#   warnings.warn("You have mixed positional and keyword "
